# %%
# %run 'examples/random_mdp/umdp.py'
# Out:
# Qlearner: step #439
# Qlearner: 500 steps done.
# Qlearner: 500 steps done.
# RLAPSE  : 500 steps done.
# Expected reward:
# 	optimal:         2.490937192212402
# 	estimated by a0: 2.490937187319591
# 	estimated by a1: 2.463971263620654
# 	estimated by rl: 2.490937187319591
# rl switching counts:
# 	to a0: 200
# 	to a1: 0
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="432">
